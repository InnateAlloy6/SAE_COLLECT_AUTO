# %% [markdown]
# @author: Diego CASAS BARCENAS, Romain SALMERON, Leo Jean UNITE

# %% [markdown]
# # Étape 1 : Chargement et exploration des données
# On va commencer par :
#
# 1. Charger le fichier CSV dans un notebook Jupyter.
# 2. Explorer les colonnes pour identifier les données utiles à la recherche des coordonnées (adresse, code postal, ville, etc.).
# 3. Vérifier la qualité des données (valeurs manquantes, incohérences).

# %%
import pandas as pd

# Charger le fichier CSV
file_path = 'data/BDCOM_2023(in).csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Aperçu des premières lignes
print(df.head())

# Vérification des colonnes disponibles
print(df.columns)

# Vérification des valeurs manquantes
print(df.isnull().sum())
# Out:
#                   X             Y  OBJECTID   c_ord  arro  qua           xbis  \
# 0  651791.048600003  6.862992e+06       1.0  1311.0   1.0  2.0  651792.345590
# 1       652152.0612  6.862579e+06       2.0  1464.0   1.0  2.0  652152.061200
# 2  651430.135700002  6.862714e+06       4.0  1623.0   1.0  3.0  651430.135700
# 3  651133.490999997  6.862932e+06       6.0  2087.0   1.0  3.0  651130.053214
# 4  651124.613200001  6.863066e+06       7.0  2157.0   1.0  3.0  651124.613200
#
#            ybis    num  let  ... codact                   ens  bio surf cc_id  \
# 0  6.862996e+06   25.0  NaN  ...  CB107                   Y'S  0.0  1.0   0.0
# 1  6.862579e+06    1.0  NaN  ...  CC301        ALAIN AFFLELOU  0.0  1.0   1.0
# 2  6.862714e+06  196.0  NaN  ...  CH106         ENZA FAMIGLIA  0.0  1.0   0.0
# 3  6.862939e+06    7.0  NaN  ...  SA202          JULIE BEAUTE  0.0  1.0   0.0
# 4  6.863066e+06   20.0  NaN  ...  CD201  HOME AUTOUR DU MONDE  0.0  1.0   0.0
#
#   cc_niv    niv47  niv18  niv8  niv2
# 0    NaN  10301.0  103.0   3.0   1.0
# 1   -3.0  10403.0  104.0   3.0   1.0
# 2    NaN  11101.0  111.0   5.0   1.0
# 3    NaN  10802.0  108.0   4.0   1.0
# 4    NaN  10502.0  105.0   3.0   1.0
#
# [5 rows x 25 columns]
# Index(['X', 'Y', 'OBJECTID', 'c_ord', 'arro', 'qua', 'xbis', 'ybis', 'num',
#        'let', 'typ_voie', 'lib_voie', 'seq', 'sit', 'type', 'codact', 'ens',
#        'bio', 'surf', 'cc_id', 'cc_niv', 'niv47', 'niv18', 'niv8', 'niv2'],
#       dtype='object')
# X               0
# Y              26
# OBJECTID       26
# c_ord          26
# arro           26
# qua            26
# xbis           26
# ybis           26
# num            26
# let         58929
# typ_voie       26
# lib_voie       26
# seq            26
# sit            26
# type           26
# codact         26
# ens            27
# bio           178
# surf           26
# cc_id         173
# cc_niv      58790
# niv47          26
# niv18          26
# niv8           26
# niv2           26
# dtype: int64

# %% [markdown]
# ## Supposons que l'adresse complète soit dans une colonne "adresse"

# %%
# Créer un fichier CSV avec uniquement les adresses à géocoder
df['adresse'] = df['num'].astype(str) + ' ' + df['let'].fillna('') + ' ' + df['typ_voie'] + ' ' + df['lib_voie'] + ', Paris ' + df['arro'].astype(str)
df[['adresse']].to_csv("data/export_for_search.csv", index=False, encoding='ISO-8859-1')

# %% [markdown]
# # Étape 2 : Envoyer les adresses à l'API

# %%
import requests

# URL de l'API du gouvernement français pour le géocodage
url = "https://api-adresse.data.gouv.fr/search/csv/"

# Ouvrir le fichier contenant les adresses
with open("data/export_for_search.csv", "rb") as fichier:
    response = requests.post(url, files={"data": fichier})

# Vérifier si la requête a réussi
if response.status_code == 200:
    # Sauvegarder le fichier géocodé
    with open("data/result_geocoded.csv", "wb") as output:
        output.write(response.content)
    print("Géocodage réussi. Fichier sauvegardé sous 'data/result_geocoded.csv'.")
else:
    print("Erreur lors du géocodage :", response.status_code)
# Out:
# Géocodage réussi. Fichier sauvegardé sous 'data/result_geocoded.csv'.

# %% [markdown]
# # Étape 3 : Intégrer les coordonnées dans le dataset initial

# %%
# Charger les résultats géocodés
df_geocoded = pd.read_csv("data/result_geocoded.csv", encoding='ISO-8859-1')

# Fusionner avec les données originales sur la colonne "adresse"
df_final = df.merge(df_geocoded[['adresse', 'latitude', 'longitude']], on='adresse', how='left')

# Supprimer les doublons
df_final = df_final.drop_duplicates()

# Sauvegarder le fichier final enrichi
df_final.to_csv("data/BCOM2023_enriched.csv", index=False, encoding='ISO-8859-1')
print("Fichier enrichi avec coordonnées sauvegardé.")

df_final
# Out:
# Fichier enrichi avec coordonnées sauvegardé.
#                        X             Y  OBJECTID    c_ord  arro   qua  \
# 0       651791.048600003  6.862992e+06       1.0   1311.0   1.0   2.0
# 1            652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# 121     651430.135700002  6.862714e+06       4.0   1623.0   1.0   3.0
# 122     651133.490999997  6.862932e+06       6.0   2087.0   1.0   3.0
# 125     651124.613200001  6.863066e+06       7.0   2157.0   1.0   3.0
# ...                  ...           ...       ...      ...   ...   ...
# 206668  647489.307899997  6.864857e+06   83144.0  91632.0  17.0  65.0
# 206669  652283.735299997  6.865286e+06   83146.0  93037.0  18.0  70.0
# 206674  651728.560800001  6.863699e+06   83147.0  93285.0   2.0   6.0
# 206718  654109.796300001  6.862549e+06   83149.0  96027.0  11.0  42.0
# 206721  652951.748999998  6.858210e+06   83150.0  96057.0  13.0  51.0
#
#                  xbis          ybis    num  let  ... surf cc_id  cc_niv  \
# 0       651792.345590  6.862996e+06   25.0  NaN  ...  1.0   0.0     NaN
# 1       652152.061200  6.862579e+06    1.0  NaN  ...  1.0   1.0    -3.0
# 121     651430.135700  6.862714e+06  196.0  NaN  ...  1.0   0.0     NaN
# 122     651130.053214  6.862939e+06    7.0  NaN  ...  1.0   0.0     NaN
# 125     651124.613200  6.863066e+06   20.0  NaN  ...  1.0   0.0     NaN
# ...               ...           ...    ...  ...  ...  ...   ...     ...
# 206668  647489.307900  6.864857e+06    2.0  NaN  ...  1.0   0.0     NaN
# 206669  652284.036876  6.865302e+06   19.0  NaN  ...  1.0   0.0     NaN
# 206674  651728.560800  6.863699e+06   11.0  NaN  ...  1.0  15.0     0.0
# 206718  654109.796300  6.862549e+06   71.0  NaN  ...  1.0   0.0     NaN
# 206721  652951.749000  6.858210e+06   33.0  NaN  ...  1.0   0.0     NaN
#
#           niv47  niv18 niv8 niv2                                   adresse  \
# 0       10301.0  103.0  3.0  1.0               25.0  RUE LOUVRE, Paris 1.0
# 1       10403.0  104.0  3.0  1.0         1.0  RUE PIERRE LESCOT, Paris 1.0
# 121     11101.0  111.0  5.0  1.0        196.0  RUE SAINT HONORE, Paris 1.0
# 122     10802.0  108.0  4.0  1.0            7.0  RUE ARGENTEUIL, Paris 1.0
# 125     10502.0  105.0  3.0  1.0            20.0  RUE PYRAMIDES, Paris 1.0
# ...         ...    ...  ...  ...                                       ...
# 206668  11001.0  110.0  3.0  1.0  2.0  BD AURELLE DE PALADINES, Paris 17.0
# 206669  10604.0  106.0  3.0  1.0               19.0  BD BARBES, Paris 18.0
# 206674  10201.0  102.0  2.0  1.0            11.0  BD MONTMARTRE, Paris 2.0
# 206718  10401.0  104.0  3.0  1.0             71.0  BD VOLTAIRE, Paris 11.0
# 206721  11101.0  111.0  5.0  1.0            33.0  RUE CAILLAUX, Paris 13.0
#
#          latitude  longitude
# 0       49.042280   2.507517
# 1       48.862383   2.348379
# 121     48.863787   2.334511
# 122     48.865437   2.333694
# 125     48.865200   2.333120
# ...           ...        ...
# 206668  48.882656   2.282438
# 206669  48.887704   2.349532
# 206674  48.867924   2.343838
# 206718  48.852436   2.391346
# 206721  48.822594   2.360637
#
# [60855 rows x 28 columns]

# %% [markdown]
# # Étape 4 : Rechercher les sites web des commerces
# 1. Analyser les colonnes disponibles : Vérifiez si l'une des colonnes contient déjà des informations sur le site web des commerces.
# 2. Compléter les données manquantes : Si le site web est manquant, vous pouvez soit utiliser un service de recherche automatisée (comme `Google Places API`) ou un autre service d'API pour récupérer ces informations, mais attention aux quotas d'usage.

# %% [markdown]
# ## 1. Installer les librairies nécessaires
# `pip install pandas selenium beautifulsoup4`

# %%
import pandas
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ### Chargement des données

# %%
df = pandas.read_csv("data/BCOM2023_enriched.csv", encoding='ISO-8859-1')
df
# Out:
#                       X             Y  OBJECTID    c_ord  arro   qua  \
# 0      651791.048600003  6.862992e+06       1.0   1311.0   1.0   2.0
# 1           652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# 2      651430.135700002  6.862714e+06       4.0   1623.0   1.0   3.0
# 3      651133.490999997  6.862932e+06       6.0   2087.0   1.0   3.0
# 4      651124.613200001  6.863066e+06       7.0   2157.0   1.0   3.0
# ...                 ...           ...       ...      ...   ...   ...
# 60850  647489.307899997  6.864857e+06   83144.0  91632.0  17.0  65.0
# 60851  652283.735299997  6.865286e+06   83146.0  93037.0  18.0  70.0
# 60852  651728.560800001  6.863699e+06   83147.0  93285.0   2.0   6.0
# 60853  654109.796300001  6.862549e+06   83149.0  96027.0  11.0  42.0
# 60854  652951.748999998  6.858210e+06   83150.0  96057.0  13.0  51.0
#
#                 xbis          ybis    num  let  ... surf cc_id  cc_niv  \
# 0      651792.345590  6.862996e+06   25.0  NaN  ...  1.0   0.0     NaN
# 1      652152.061200  6.862579e+06    1.0  NaN  ...  1.0   1.0    -3.0
# 2      651430.135700  6.862714e+06  196.0  NaN  ...  1.0   0.0     NaN
# 3      651130.053214  6.862939e+06    7.0  NaN  ...  1.0   0.0     NaN
# 4      651124.613200  6.863066e+06   20.0  NaN  ...  1.0   0.0     NaN
# ...              ...           ...    ...  ...  ...  ...   ...     ...
# 60850  647489.307900  6.864857e+06    2.0  NaN  ...  1.0   0.0     NaN
# 60851  652284.036876  6.865302e+06   19.0  NaN  ...  1.0   0.0     NaN
# 60852  651728.560800  6.863699e+06   11.0  NaN  ...  1.0  15.0     0.0
# 60853  654109.796300  6.862549e+06   71.0  NaN  ...  1.0   0.0     NaN
# 60854  652951.749000  6.858210e+06   33.0  NaN  ...  1.0   0.0     NaN
#
#          niv47  niv18 niv8 niv2                                   adresse  \
# 0      10301.0  103.0  3.0  1.0               25.0  RUE LOUVRE, Paris 1.0
# 1      10403.0  104.0  3.0  1.0         1.0  RUE PIERRE LESCOT, Paris 1.0
# 2      11101.0  111.0  5.0  1.0        196.0  RUE SAINT HONORE, Paris 1.0
# 3      10802.0  108.0  4.0  1.0            7.0  RUE ARGENTEUIL, Paris 1.0
# 4      10502.0  105.0  3.0  1.0            20.0  RUE PYRAMIDES, Paris 1.0
# ...        ...    ...  ...  ...                                       ...
# 60850  11001.0  110.0  3.0  1.0  2.0  BD AURELLE DE PALADINES, Paris 17.0
# 60851  10604.0  106.0  3.0  1.0               19.0  BD BARBES, Paris 18.0
# 60852  10201.0  102.0  2.0  1.0            11.0  BD MONTMARTRE, Paris 2.0
# 60853  10401.0  104.0  3.0  1.0             71.0  BD VOLTAIRE, Paris 11.0
# 60854  11101.0  111.0  5.0  1.0            33.0  RUE CAILLAUX, Paris 13.0
#
#         latitude  longitude
# 0      49.042280   2.507517
# 1      48.862383   2.348379
# 2      48.863787   2.334511
# 3      48.865437   2.333694
# 4      48.865200   2.333120
# ...          ...        ...
# 60850  48.882656   2.282438
# 60851  48.887704   2.349532
# 60852  48.867924   2.343838
# 60853  48.852436   2.391346
# 60854  48.822594   2.360637
#
# [60855 rows x 28 columns]

# %% [markdown]
# ## 2. Télécharger et configurer ChromeDriver
# Pour que `selenium` fonctionne comme ce qui suit, sous Windows, il est nécessaire d’avoir télécharger l’exécutable [chromedriver](https://storage.googleapis.com/chrome-for-testing-public/132.0.6834.110/win64/chromedriver-win64.zip) dans le répertoire de travail de Python. Vous pouvez récupérer les versions stables sur [cette page](https://googlechromelabs.github.io/chrome-for-testing/#stable) (copier-coller le lien HTML dans la barre du navigateur pour télécharger le fichier).
#
# `pip install selenium` in Terminal
# ### Configurer le navigateur Selenium (assurez-vous que ChromeDriver est installé)

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ## Création de l’URL à récupérer
# On créé l’URL de la page qu’on souhaite récupérer. Pour faire une recherche dans Google Maps, il est préférable de mettre le nom de l’établissement, ainsi que les coordonnées géographiques de celui-ci.

# %%
base_url = "https://www.google.com/maps/search/"
place_info = "IUT+paris+rives+de+seine"
comp_url = "/@48.8489968,2.3125954,12z"

url = base_url + place_info + comp_url
url
# Out:
# 'https://www.google.com/maps/search/IUT+paris+rives+de+seine/@48.8489968,2.3125954,12z'

# %% [markdown]
# ## Premier lancement du navigateur
# Pour rappel, **NE FERMEZ PAS LA FENETRE** mais cliquer sur Tout autoriser

# %%
driver.get(url)

# %% [markdown]
# ## Fonction pour création de l'URL
# On reprend la fonction vue dans la séance 1, avec une petite amélioration pour mettre le numéro de l'adresse en entier.

# %%
def f(v, fin = False):
    r = ""
    if not(pandas.isna(v)):
        if isinstance(v, float):
            r += str(int(v))
        else:
            r += str(v)
        if not(fin):
            r += "+"
    return r

# %% [markdown]
# ### Code test de recherche & livraison

# %%
# Liste pour stocker les résultats
site = []
livraison = []

# Limiter le DataFrame aux n premières lignes
df_subset = df.head(5)

# Boucle pour parcourir les données et rechercher les sites web
for i in range(df_subset.shape[0]):
    place_info = f(df["num"][i]) + f(df["let"][i]) + f(df["typ_voie"][i]) + f(df["lib_voie"][i], True)
    comp_url = "/@" + str(df["latitude"][i]) + "," + str(df["longitude"][i])
    url = base_url + place_info + comp_url
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    # Extraction du site web
    results = soup.select("a[aria-label*='Site Web']")
    
    # Si un résultat est trouvé, ajoutez le lien, sinon ajoutez None
    if results:
        href = results[0]["href"]
    else:
        href = None
    
    site.append(href)  # Ajouter le lien du site web ou None

    # Recherche de la mention "livraison" (à adapter selon la structure des sites)
    if "livraison" in html.lower() or "deliver" in html.lower() or "uber" in html.lower():
        livraison.append("Oui")
    else:
        livraison.append("Non")

    time.sleep(1)  # Respecter les délais pour éviter d'être bloqué

# Ajouter les résultats dans le sous-ensemble de DataFrame
df_subset["site"] = site
df_subset["livraison"] = livraison

# Sauvegarder le fichier avec les nouveaux résultats
df_subset.to_csv("data/BDCOM_2023_avec_site_et_livraison_test.csv", index=False)

print("Fichier sauvegardé pour les n premières adresses.")
# Out:
# Fichier sauvegardé pour les n premières adresses.
# C:\Users\dicab\AppData\Local\Temp\ipykernel_29044\184220792.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["site"] = site
# C:\Users\dicab\AppData\Local\Temp\ipykernel_29044\184220792.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["livraison"] = livraison

# %% [markdown]
# ### Code de recherche web & livraison

# %%
# Initialisation des listes pour stocker les résultats
site = []
livraison = []

for i in range(df.shape[0]):
    try:
        # Création de l'URL de recherche
        place_info = f(df["num"][i]) + f(df["let"][i]) + f(df["typ_voie"][i]) + f(df["lib_voie"][i], True)
        comp_url = "/@" + str(df["latitude"][i]) + "," + str(df["longitude"][i])
        url = base_url + place_info + comp_url
        
        # Ouvrir l'URL dans le navigateur Selenium
        driver.get(url)
        time.sleep(2)  # Pause pour charger la page

        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

        # Extraction du site web
        results = soup.select("a[aria-label*='Site Web']")
        
        # Si un site web est trouvé, stocker le lien, sinon None
        if results:
            href = results[0]["href"]
        else:
            href = None
        
        site.append(href)

        # Recherche de la mention "livraison" dans la page
        if "livraison" in html.lower() or "deliver" in html.lower() or "uber" in html.lower():
            livraison.append("Oui")
        else:
            livraison.append("Non")

        # Affichage de la progression
        print(f"Traitement de l'adresse {i + 1}/{df.shape[0]} : {href}, Livraison: {livraison[-1]}")

    except Exception as e:
        print(f"Erreur à l'adresse {i + 1}/{df.shape[0]} : {str(e)}")
        site.append(None)
        livraison.append(None)

    time.sleep(1)  # Pause pour éviter le blocage de Google

# Ajout des résultats au DataFrame
df["site"] = site
df["livraison"] = livraison

# Sauvegarde du fichier enrichi
df.to_csv("data/BDCOM_2023_avec_site_et_livraison.csv", index=False)

print("Traitement terminé et fichier sauvegardé.")
# Out:
# Traitement de l'adresse 1/60855 : None, Livraison: Non
# Traitement de l'adresse 2/60855 : None, Livraison: Non
# Traitement de l'adresse 3/60855 : None, Livraison: Non
# Traitement de l'adresse 4/60855 : None, Livraison: Non
# Traitement de l'adresse 5/60855 : None, Livraison: Non
# Traitement de l'adresse 6/60855 : None, Livraison: Non
# Traitement de l'adresse 7/60855 : None, Livraison: Non
# Traitement de l'adresse 8/60855 : None, Livraison: Non
# Traitement de l'adresse 9/60855 : None, Livraison: Non
# Traitement de l'adresse 10/60855 : None, Livraison: Non
# Traitement de l'adresse 11/60855 : None, Livraison: Non
# Traitement de l'adresse 12/60855 : None, Livraison: Non
# Traitement de l'adresse 13/60855 : None, Livraison: Non
# Traitement de l'adresse 14/60855 : None, Livraison: Non
# Traitement de l'adresse 15/60855 : None, Livraison: Non
# Traitement de l'adresse 16/60855 : None, Livraison: Non
# Traitement de l'adresse 17/60855 : None, Livraison: Non
# Traitement de l'adresse 18/60855 : None, Livraison: Non
# Traitement de l'adresse 19/60855 : None, Livraison: Non
# Traitement de l'adresse 20/60855 : None, Livraison: Non
# Traitement de l'adresse 21/60855 : None, Livraison: Non
# Traitement de l'adresse 22/60855 : None, Livraison: Oui
# Traitement de l'adresse 23/60855 : None, Livraison: Non
# Traitement de l'adresse 24/60855 : None, Livraison: Non
# Traitement de l'adresse 25/60855 : None, Livraison: Non
# Traitement de l'adresse 26/60855 : None, Livraison: Non
# Traitement de l'adresse 27/60855 : None, Livraison: Non
# Traitement de l'adresse 28/60855 : None, Livraison: Non
# Traitement de l'adresse 29/60855 : None, Livraison: Non
# Traitement de l'adresse 30/60855 : None, Livraison: Non
# Traitement de l'adresse 31/60855 : None, Livraison: Non
# Traitement de l'adresse 32/60855 : None, Livraison: Non
# Traitement de l'adresse 33/60855 : None, Livraison: Non
# Traitement de l'adresse 34/60855 : None, Livraison: Non
# Traitement de l'adresse 35/60855 : None, Livraison: Non
# Traitement de l'adresse 36/60855 : None, Livraison: Non
# Traitement de l'adresse 37/60855 : None, Livraison: Non
# Traitement de l'adresse 38/60855 : None, Livraison: Non
# Traitement de l'adresse 39/60855 : None, Livraison: Non
# Traitement de l'adresse 40/60855 : None, Livraison: Non
# Traitement de l'adresse 41/60855 : None, Livraison: Non
# Traitement de l'adresse 42/60855 : None, Livraison: Non
# Traitement de l'adresse 43/60855 : None, Livraison: Non
# Traitement de l'adresse 44/60855 : None, Livraison: Non
# Traitement de l'adresse 45/60855 : None, Livraison: Non
# Traitement de l'adresse 46/60855 : None, Livraison: Non
# Traitement de l'adresse 47/60855 : None, Livraison: Non
# Traitement de l'adresse 48/60855 : None, Livraison: Non
# Traitement de l'adresse 49/60855 : None, Livraison: Non
# Traitement de l'adresse 50/60855 : None, Livraison: Non
# Traitement de l'adresse 51/60855 : None, Livraison: Non
# Traitement de l'adresse 52/60855 : None, Livraison: Non
# Traitement de l'adresse 53/60855 : None, Livraison: Non
# Traitement de l'adresse 54/60855 : None, Livraison: Non
# Traitement de l'adresse 55/60855 : None, Livraison: Non
# Traitement de l'adresse 56/60855 : None, Livraison: Non
# Traitement de l'adresse 57/60855 : None, Livraison: Non
# Traitement de l'adresse 58/60855 : None, Livraison: Non
# Traitement de l'adresse 59/60855 : None, Livraison: Non
# Traitement de l'adresse 60/60855 : None, Livraison: Non
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 14
#      12 # Ouvrir l'URL dans le navigateur Selenium
#      13 driver.get(url)
# ---> 14 time.sleep(2)  # Pause pour charger la page
#      16 html = driver.page_source
#      17 soup = BeautifulSoup(html, "html.parser")
#
# KeyboardInterrupt:
