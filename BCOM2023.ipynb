# %% [markdown]
# @author: Diego CASAS BARCENAS, Romain SALMERON, Leo Jean UNITE

# %% [markdown]
# # Étape 1 : Chargement et exploration des données
# On va commencer par :
#
# 1. Charger le fichier CSV dans un notebook Jupyter.
# 2. Explorer les colonnes pour identifier les données utiles à la recherche des coordonnées (adresse, code postal, ville, etc.).
# 3. Vérifier la qualité des données (valeurs manquantes, incohérences).

# %%
import pandas as pd

# Charger le fichier CSV
file_path = 'data/BDCOM_2023(in).csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Aperçu des premières lignes
print(df.head())

# Vérification des colonnes disponibles
print(df.columns)

# Vérification des valeurs manquantes
print(df.isnull().sum())
# Out:
#                   X             Y  OBJECTID   c_ord  arro  qua           xbis  \
# 0  651791.048600003  6.862992e+06       1.0  1311.0   1.0  2.0  651792.345590
# 1       652152.0612  6.862579e+06       2.0  1464.0   1.0  2.0  652152.061200
# 2  651430.135700002  6.862714e+06       4.0  1623.0   1.0  3.0  651430.135700
# 3  651133.490999997  6.862932e+06       6.0  2087.0   1.0  3.0  651130.053214
# 4  651124.613200001  6.863066e+06       7.0  2157.0   1.0  3.0  651124.613200
#
#            ybis    num  let  ... codact                   ens  bio surf cc_id  \
# 0  6.862996e+06   25.0  NaN  ...  CB107                   Y'S  0.0  1.0   0.0
# 1  6.862579e+06    1.0  NaN  ...  CC301        ALAIN AFFLELOU  0.0  1.0   1.0
# 2  6.862714e+06  196.0  NaN  ...  CH106         ENZA FAMIGLIA  0.0  1.0   0.0
# 3  6.862939e+06    7.0  NaN  ...  SA202          JULIE BEAUTE  0.0  1.0   0.0
# 4  6.863066e+06   20.0  NaN  ...  CD201  HOME AUTOUR DU MONDE  0.0  1.0   0.0
#
#   cc_niv    niv47  niv18  niv8  niv2
# 0    NaN  10301.0  103.0   3.0   1.0
# 1   -3.0  10403.0  104.0   3.0   1.0
# 2    NaN  11101.0  111.0   5.0   1.0
# 3    NaN  10802.0  108.0   4.0   1.0
# 4    NaN  10502.0  105.0   3.0   1.0
#
# [5 rows x 25 columns]
# Index(['X', 'Y', 'OBJECTID', 'c_ord', 'arro', 'qua', 'xbis', 'ybis', 'num',
#        'let', 'typ_voie', 'lib_voie', 'seq', 'sit', 'type', 'codact', 'ens',
#        'bio', 'surf', 'cc_id', 'cc_niv', 'niv47', 'niv18', 'niv8', 'niv2'],
#       dtype='object')
# X               0
# Y              26
# OBJECTID       26
# c_ord          26
# arro           26
# qua            26
# xbis           26
# ybis           26
# num            26
# let         58929
# typ_voie       26
# lib_voie       26
# seq            26
# sit            26
# type           26
# codact         26
# ens            27
# bio           178
# surf           26
# cc_id         173
# cc_niv      58790
# niv47          26
# niv18          26
# niv8           26
# niv2           26
# dtype: int64

# %% [markdown]
# ## Supposons que l'adresse complète soit dans une colonne "adresse"

# %%
# Créer un fichier CSV avec uniquement les adresses à géocoder
df['adresse'] = df['num'].astype(str) + ' ' + df['let'].fillna('') + ' ' + df['typ_voie'] + ' ' + df['lib_voie'] + ', Paris ' + df['arro'].astype(str)
df[['adresse']].to_csv("data/export_for_search.csv", index=False, encoding='ISO-8859-1')

# %% [markdown]
# # Étape 2 : Envoyer les adresses à l'API

# %%
import requests

# URL de l'API du gouvernement français pour le géocodage
url = "https://api-adresse.data.gouv.fr/search/csv/"

# Ouvrir le fichier contenant les adresses
with open("data/export_for_search.csv", "rb") as fichier:
    response = requests.post(url, files={"data": fichier})

# Vérifier si la requête a réussi
if response.status_code == 200:
    # Sauvegarder le fichier géocodé
    with open("data/result_geocoded.csv", "wb") as output:
        output.write(response.content)
    print("Géocodage réussi. Fichier sauvegardé sous 'data/result_geocoded.csv'.")
else:
    print("Erreur lors du géocodage :", response.status_code)
# Out:
# Géocodage réussi. Fichier sauvegardé sous 'data/result_geocoded.csv'.

# %% [markdown]
# # Étape 3 : Intégrer les coordonnées dans le dataset initial

# %%
# Charger les résultats géocodés
df_geocoded = pd.read_csv("data/result_geocoded.csv", encoding='ISO-8859-1')

# Fusionner avec les données originales sur la colonne "adresse"
df_final = df.merge(df_geocoded[['adresse', 'latitude', 'longitude']], on='adresse', how='left')

# Sauvegarder le fichier final enrichi
df_final.to_csv("data/BCOM2023_enriched.csv", index=False, encoding='ISO-8859-1')
print("Fichier enrichi avec coordonnées sauvegardé.")
# Out:
# Fichier enrichi avec coordonnées sauvegardé.

# %% [markdown]
# # Étape 4 : Rechercher les sites web des commerces
# 1. Analyser les colonnes disponibles : Vérifiez si l'une des colonnes contient déjà des informations sur le site web des commerces.
# 2. Compléter les données manquantes : Si le site web est manquant, vous pouvez soit utiliser un service de recherche automatisée (comme `Google Places API`) ou un autre service d'API pour récupérer ces informations, mais attention aux quotas d'usage.

# %% [markdown]
# ## 1. Installer les librairies nécessaires
# `pip install pandas selenium beautifulsoup4`

# %%
import pandas
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ### Chargement des données

# %%
df = pandas.read_csv("data/BCOM2023_enriched.csv", encoding='ISO-8859-1')
df
# Out:
# C:\Users\leoun\AppData\Local\Temp\ipykernel_11896\2588200154.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv("data/BCOM2023_enriched.csv", encoding='ISO-8859-1')
#                        X             Y  OBJECTID    c_ord  arro   qua  \
# 0       651791.048600003  6.862992e+06       1.0   1311.0   1.0   2.0
# 1            652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# 2            652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# 3            652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# 4            652152.0612  6.862579e+06       2.0   1464.0   1.0   2.0
# ...                  ...           ...       ...      ...   ...   ...
# 206718       654109.7963  6.862549e+06   83149.0  96027.0  11.0  42.0
# 206719       654109.7963  6.862549e+06   83149.0  96027.0  11.0  42.0
# 206720       654109.7963  6.862549e+06   83149.0  96027.0  11.0  42.0
# 206721        652951.749  6.858210e+06   83150.0  96057.0  13.0  51.0
# 206722        652951.749  6.858210e+06   83150.0  96057.0  13.0  51.0
#
#                 xbis          ybis   num  let  ... surf cc_id  cc_niv  \
# 0       651792.34559  6.862996e+06  25.0  NaN  ...  1.0   0.0     NaN
# 1       652152.06120  6.862579e+06   1.0  NaN  ...  1.0   1.0    -3.0
# 2       652152.06120  6.862579e+06   1.0  NaN  ...  1.0   1.0    -3.0
# 3       652152.06120  6.862579e+06   1.0  NaN  ...  1.0   1.0    -3.0
# 4       652152.06120  6.862579e+06   1.0  NaN  ...  1.0   1.0    -3.0
# ...              ...           ...   ...  ...  ...  ...   ...     ...
# 206718  654109.79630  6.862549e+06  71.0  NaN  ...  1.0   0.0     NaN
# 206719  654109.79630  6.862549e+06  71.0  NaN  ...  1.0   0.0     NaN
# 206720  654109.79630  6.862549e+06  71.0  NaN  ...  1.0   0.0     NaN
# 206721  652951.74900  6.858210e+06  33.0  NaN  ...  1.0   0.0     NaN
# 206722  652951.74900  6.858210e+06  33.0  NaN  ...  1.0   0.0     NaN
#
#           niv47  niv18 niv8 niv2                            adresse  \
# 0       10301.0  103.0  3.0  1.0        25.0  RUE LOUVRE, Paris 1.0
# 1       10403.0  104.0  3.0  1.0  1.0  RUE PIERRE LESCOT, Paris 1.0
# 2       10403.0  104.0  3.0  1.0  1.0  RUE PIERRE LESCOT, Paris 1.0
# 3       10403.0  104.0  3.0  1.0  1.0  RUE PIERRE LESCOT, Paris 1.0
# 4       10403.0  104.0  3.0  1.0  1.0  RUE PIERRE LESCOT, Paris 1.0
# ...         ...    ...  ...  ...                                ...
# 206718  10401.0  104.0  3.0  1.0      71.0  BD VOLTAIRE, Paris 11.0
# 206719  10401.0  104.0  3.0  1.0      71.0  BD VOLTAIRE, Paris 11.0
# 206720  10401.0  104.0  3.0  1.0      71.0  BD VOLTAIRE, Paris 11.0
# 206721  11101.0  111.0  5.0  1.0     33.0  RUE CAILLAUX, Paris 13.0
# 206722  11101.0  111.0  5.0  1.0     33.0  RUE CAILLAUX, Paris 13.0
#
#          latitude  longitude
# 0       49.042280   2.507517
# 1       48.862383   2.348379
# 2       48.862383   2.348379
# 3       48.862383   2.348379
# 4       48.862383   2.348379
# ...           ...        ...
# 206718  48.852436   2.391346
# 206719  48.852436   2.391346
# 206720  48.852436   2.391346
# 206721  48.822594   2.360637
# 206722  48.822594   2.360637
#
# [206723 rows x 28 columns]

# %% [markdown]
# ## 2. Télécharger et configurer ChromeDriver
# Pour que `selenium` fonctionne comme ce qui suit, sous Windows, il est nécessaire d’avoir télécharger l’exécutable [chromedriver](https://storage.googleapis.com/chrome-for-testing-public/132.0.6834.110/win64/chromedriver-win64.zip) dans le répertoire de travail de Python. Vous pouvez récupérer les versions stables sur [cette page](https://googlechromelabs.github.io/chrome-for-testing/#stable) (copier-coller le lien HTML dans la barre du navigateur pour télécharger le fichier).
#
# `pip install selenium` in Terminal
# ### Configurer le navigateur Selenium (assurez-vous que ChromeDriver est installé)

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ## Création de l’URL à récupérer
# On créé l’URL de la page qu’on souhaite récupérer. Pour faire une recherche dans Google Maps, il est préférable de mettre le nom de l’établissement, ainsi que les coordonnées géographiques de celui-ci.

# %%
base_url = "https://www.google.com/maps/search/"
place_info = "IUT+paris+rives+de+seine"
comp_url = "/@48.8489968,2.3125954,12z"

url = base_url + place_info + comp_url
url
# Out:
# 'https://www.google.com/maps/search/IUT+paris+rives+de+seine/@48.8489968,2.3125954,12z'

# %% [markdown]
# ## Premier lancement du navigateur
# Pour rappel, **NE FERMEZ PAS LA FENETRE** mais cliquer sur Tout autoriser

# %%
driver.get(url)

# %% [markdown]
# ## Fonction pour création de l'URL
# On reprend la fonction vue dans la séance 1, avec une petite amélioration pour mettre le numéro de l'adresse en entier.

# %%
def f(v, fin = False):
    r = ""
    if not(pandas.isna(v)):
        if isinstance(v, float):
            r += str(int(v))
        else:
            r += str(v)
        if not(fin):
            r += "+"
    return r

# %% [markdown]
# ### Code test de recherche & livraison

# %%
# Liste pour stocker les résultats
site = []
livraison = []

# Limiter le DataFrame aux n premières lignes
df_subset = df.head(5)

# Boucle pour parcourir les données et rechercher les sites web
for i in range(df_subset.shape[0]):
    place_info = f(df["num"][i]) + f(df["let"][i]) + f(df["typ_voie"][i]) + f(df["lib_voie"][i], True)
    comp_url = "/@" + str(df["latitude"][i]) + "," + str(df["longitude"][i])
    url = base_url + place_info + comp_url
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    # Extraction du site web
    results = soup.select("a[aria-label*='Site Web']")
    
    # Si un résultat est trouvé, ajoutez le lien, sinon ajoutez None
    if results:
        href = results[0]["href"]
    else:
        href = None
    
    site.append(href)  # Ajouter le lien du site web ou None

    # Recherche de la mention "livraison" (à adapter selon la structure des sites)
    if "livraison" in html.lower() or "deliver" in html.lower() or "uber" in html.lower():
        livraison.append("Oui")
    else:
        livraison.append("Non")

    time.sleep(1)  # Respecter les délais pour éviter d'être bloqué

# Ajouter les résultats dans le sous-ensemble de DataFrame
df_subset["site"] = site
df_subset["livraison"] = livraison

# Sauvegarder le fichier avec les nouveaux résultats
df_subset.to_csv("data/BDCOM_2023_avec_site_et_livraison_test.csv", index=False)

print("Fichier sauvegardé pour les n premières adresses.")
# Out:
# C:\Users\leoun\AppData\Local\Temp\ipykernel_11896\3900287181.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["site"] = site
# C:\Users\leoun\AppData\Local\Temp\ipykernel_11896\3900287181.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset["livraison"] = livraison
# Fichier sauvegardé pour les n premières adresses.

# %% [markdown]
# ### Code de recherche web & livraison

# %%
# Initialisation des listes pour stocker les résultats
site = []
livraison = []

for i in range(df.shape[0]):
    try:
        # Création de l'URL de recherche
        place_info = f(df["num"][i]) + f(df["let"][i]) + f(df["typ_voie"][i]) + f(df["lib_voie"][i], True)
        comp_url = "/@" + str(df["latitude"][i]) + "," + str(df["longitude"][i])
        url = base_url + place_info + comp_url
        
        # Ouvrir l'URL dans le navigateur Selenium
        driver.get(url)
        time.sleep(2)  # Pause pour charger la page

        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

        # Extraction du site web
        results = soup.select("a[aria-label*='Site Web']")
        
        # Si un site web est trouvé, stocker le lien, sinon None
        if results:
            href = results[0]["href"]
        else:
            href = None
        
        site.append(href)

        # Recherche de la mention "livraison" dans la page
        if "livraison" in html.lower() or "deliver" in html.lower() or "uber" in html.lower():
            livraison.append("Oui")
        else:
            livraison.append("Non")

        # Affichage de la progression
        print(f"Traitement de l'adresse {i + 1}/{df.shape[0]} : {href}, Livraison: {livraison[-1]}")

    except Exception as e:
        print(f"Erreur à l'adresse {i + 1}/{df.shape[0]} : {str(e)}")
        site.append(None)
        livraison.append(None)

    time.sleep(1)  # Pause pour éviter le blocage de Google

# Ajout des résultats au DataFrame
df["site"] = site
df["livraison"] = livraison

# Sauvegarde du fichier enrichi
df.to_csv("data/BDCOM_2023_avec_site_et_livraison.csv", index=False)

print("Traitement terminé et fichier sauvegardé.")
# Out:
# Traitement de l'adresse 1/206723 : None, Livraison: Non
# Traitement de l'adresse 2/206723 : None, Livraison: Non
# Traitement de l'adresse 3/206723 : None, Livraison: Non
# Traitement de l'adresse 4/206723 : None, Livraison: Non
# Traitement de l'adresse 5/206723 : None, Livraison: Non
# Traitement de l'adresse 6/206723 : None, Livraison: Non
# Traitement de l'adresse 7/206723 : None, Livraison: Non
# Traitement de l'adresse 8/206723 : None, Livraison: Non
# Traitement de l'adresse 9/206723 : None, Livraison: Non
# Traitement de l'adresse 10/206723 : None, Livraison: Non
# Traitement de l'adresse 11/206723 : None, Livraison: Non
# Traitement de l'adresse 12/206723 : None, Livraison: Non
# Traitement de l'adresse 13/206723 : None, Livraison: Non
# Traitement de l'adresse 14/206723 : None, Livraison: Non
# Traitement de l'adresse 15/206723 : None, Livraison: Non
# Traitement de l'adresse 16/206723 : None, Livraison: Non
# Traitement de l'adresse 17/206723 : None, Livraison: Non
# Traitement de l'adresse 18/206723 : None, Livraison: Non
# Traitement de l'adresse 19/206723 : None, Livraison: Non
# Traitement de l'adresse 20/206723 : None, Livraison: Non
# Traitement de l'adresse 21/206723 : None, Livraison: Non
# Traitement de l'adresse 22/206723 : None, Livraison: Non
# Traitement de l'adresse 23/206723 : None, Livraison: Non
# Traitement de l'adresse 24/206723 : None, Livraison: Non
# Traitement de l'adresse 25/206723 : None, Livraison: Non
# Traitement de l'adresse 26/206723 : None, Livraison: Non
# Traitement de l'adresse 27/206723 : None, Livraison: Non
# Traitement de l'adresse 28/206723 : None, Livraison: Non
# Traitement de l'adresse 29/206723 : None, Livraison: Non
# Traitement de l'adresse 30/206723 : None, Livraison: Non
# Traitement de l'adresse 31/206723 : None, Livraison: Non
# Traitement de l'adresse 32/206723 : None, Livraison: Non
# Traitement de l'adresse 33/206723 : None, Livraison: Non
# Traitement de l'adresse 34/206723 : None, Livraison: Non
# Traitement de l'adresse 35/206723 : None, Livraison: Non
# Traitement de l'adresse 36/206723 : None, Livraison: Non
# Traitement de l'adresse 37/206723 : None, Livraison: Non
# Traitement de l'adresse 38/206723 : None, Livraison: Non
# Traitement de l'adresse 39/206723 : None, Livraison: Non
# Traitement de l'adresse 40/206723 : None, Livraison: Non
# Traitement de l'adresse 41/206723 : None, Livraison: Non
# Traitement de l'adresse 42/206723 : None, Livraison: Non
# Traitement de l'adresse 43/206723 : None, Livraison: Non
# Traitement de l'adresse 44/206723 : None, Livraison: Non
# Traitement de l'adresse 45/206723 : None, Livraison: Non
# Traitement de l'adresse 46/206723 : None, Livraison: Non
# Traitement de l'adresse 47/206723 : None, Livraison: Non
# Traitement de l'adresse 48/206723 : None, Livraison: Non
# Traitement de l'adresse 49/206723 : None, Livraison: Non
# Traitement de l'adresse 50/206723 : None, Livraison: Non
# Traitement de l'adresse 51/206723 : None, Livraison: Non
# Traitement de l'adresse 52/206723 : None, Livraison: Non
# Traitement de l'adresse 53/206723 : None, Livraison: Non
# Traitement de l'adresse 54/206723 : None, Livraison: Non
# Traitement de l'adresse 55/206723 : None, Livraison: Non
# Traitement de l'adresse 56/206723 : None, Livraison: Non
# Traitement de l'adresse 57/206723 : None, Livraison: Non
# Traitement de l'adresse 58/206723 : None, Livraison: Non
# Traitement de l'adresse 59/206723 : None, Livraison: Non
# Traitement de l'adresse 60/206723 : None, Livraison: Non
# Traitement de l'adresse 61/206723 : None, Livraison: Non
# Traitement de l'adresse 62/206723 : None, Livraison: Non
# Traitement de l'adresse 63/206723 : None, Livraison: Non
# Traitement de l'adresse 64/206723 : None, Livraison: Non
# Traitement de l'adresse 65/206723 : None, Livraison: Non
# Traitement de l'adresse 66/206723 : None, Livraison: Non
# Traitement de l'adresse 67/206723 : None, Livraison: Non
# Traitement de l'adresse 68/206723 : None, Livraison: Non
# Traitement de l'adresse 69/206723 : None, Livraison: Non
# Traitement de l'adresse 70/206723 : None, Livraison: Non
# Traitement de l'adresse 71/206723 : None, Livraison: Non
# Traitement de l'adresse 72/206723 : None, Livraison: Non
# Traitement de l'adresse 73/206723 : None, Livraison: Non
# Traitement de l'adresse 74/206723 : None, Livraison: Non
# Traitement de l'adresse 75/206723 : None, Livraison: Non
# Traitement de l'adresse 76/206723 : None, Livraison: Non
# Traitement de l'adresse 77/206723 : None, Livraison: Non
# Traitement de l'adresse 78/206723 : None, Livraison: Non
# Traitement de l'adresse 79/206723 : None, Livraison: Non
# Traitement de l'adresse 80/206723 : None, Livraison: Non
# Traitement de l'adresse 81/206723 : None, Livraison: Non
# Traitement de l'adresse 82/206723 : None, Livraison: Non
# Traitement de l'adresse 83/206723 : None, Livraison: Non
# Traitement de l'adresse 84/206723 : None, Livraison: Non
# Traitement de l'adresse 85/206723 : None, Livraison: Non
# Traitement de l'adresse 86/206723 : None, Livraison: Non
# Traitement de l'adresse 87/206723 : None, Livraison: Non
# Traitement de l'adresse 88/206723 : None, Livraison: Non
# Traitement de l'adresse 89/206723 : None, Livraison: Non
# Traitement de l'adresse 90/206723 : None, Livraison: Non
# Traitement de l'adresse 91/206723 : None, Livraison: Non
# Traitement de l'adresse 92/206723 : None, Livraison: Non
# Traitement de l'adresse 93/206723 : None, Livraison: Non
# Traitement de l'adresse 94/206723 : None, Livraison: Non
# Traitement de l'adresse 95/206723 : None, Livraison: Non
# Traitement de l'adresse 96/206723 : None, Livraison: Non
# Traitement de l'adresse 97/206723 : None, Livraison: Non
# Traitement de l'adresse 98/206723 : None, Livraison: Non
# Traitement de l'adresse 99/206723 : None, Livraison: Non
# Traitement de l'adresse 100/206723 : None, Livraison: Non
# Traitement de l'adresse 101/206723 : None, Livraison: Non
# Traitement de l'adresse 102/206723 : None, Livraison: Non
# Traitement de l'adresse 103/206723 : None, Livraison: Non
# Traitement de l'adresse 104/206723 : None, Livraison: Non
# Traitement de l'adresse 105/206723 : None, Livraison: Non
# Traitement de l'adresse 106/206723 : None, Livraison: Non
# Traitement de l'adresse 107/206723 : None, Livraison: Non
# Traitement de l'adresse 108/206723 : None, Livraison: Non
# Traitement de l'adresse 109/206723 : None, Livraison: Non
# Traitement de l'adresse 110/206723 : None, Livraison: Non
# Traitement de l'adresse 111/206723 : None, Livraison: Non
# Traitement de l'adresse 112/206723 : None, Livraison: Non
# Traitement de l'adresse 113/206723 : None, Livraison: Non
# Traitement de l'adresse 114/206723 : None, Livraison: Non
# Traitement de l'adresse 115/206723 : None, Livraison: Non
# Traitement de l'adresse 116/206723 : None, Livraison: Non
# Traitement de l'adresse 117/206723 : None, Livraison: Non
# Traitement de l'adresse 118/206723 : None, Livraison: Non
# Traitement de l'adresse 119/206723 : None, Livraison: Non
# Traitement de l'adresse 120/206723 : None, Livraison: Non
# Traitement de l'adresse 121/206723 : None, Livraison: Non
# Traitement de l'adresse 122/206723 : None, Livraison: Non
# Traitement de l'adresse 123/206723 : None, Livraison: Non
# Traitement de l'adresse 124/206723 : None, Livraison: Non
# Traitement de l'adresse 125/206723 : None, Livraison: Non
# Traitement de l'adresse 126/206723 : None, Livraison: Non
# Traitement de l'adresse 127/206723 : None, Livraison: Non
# Traitement de l'adresse 128/206723 : None, Livraison: Non
# Traitement de l'adresse 129/206723 : None, Livraison: Non
# Traitement de l'adresse 130/206723 : None, Livraison: Non
# Traitement de l'adresse 131/206723 : None, Livraison: Non
# Traitement de l'adresse 132/206723 : None, Livraison: Non
# Traitement de l'adresse 133/206723 : None, Livraison: Non
# Traitement de l'adresse 134/206723 : None, Livraison: Non
# Traitement de l'adresse 135/206723 : None, Livraison: Non
# Traitement de l'adresse 136/206723 : None, Livraison: Non
# Traitement de l'adresse 137/206723 : None, Livraison: Non
# Traitement de l'adresse 138/206723 : None, Livraison: Non
# Traitement de l'adresse 139/206723 : None, Livraison: Non
# Traitement de l'adresse 140/206723 : None, Livraison: Non
# Traitement de l'adresse 141/206723 : None, Livraison: Non
# Traitement de l'adresse 142/206723 : None, Livraison: Non
# Traitement de l'adresse 143/206723 : None, Livraison: Non
# Traitement de l'adresse 144/206723 : None, Livraison: Non
# Traitement de l'adresse 145/206723 : None, Livraison: Non
# Traitement de l'adresse 146/206723 : None, Livraison: Non
# Traitement de l'adresse 147/206723 : None, Livraison: Non
# Traitement de l'adresse 148/206723 : None, Livraison: Non
# Traitement de l'adresse 149/206723 : None, Livraison: Non
# Traitement de l'adresse 150/206723 : None, Livraison: Non
# Traitement de l'adresse 151/206723 : None, Livraison: Non
# Traitement de l'adresse 152/206723 : None, Livraison: Non
# Traitement de l'adresse 153/206723 : None, Livraison: Non
# Traitement de l'adresse 154/206723 : None, Livraison: Non
# Traitement de l'adresse 155/206723 : None, Livraison: Non
# Traitement de l'adresse 156/206723 : None, Livraison: Non
# Traitement de l'adresse 157/206723 : None, Livraison: Non
# Traitement de l'adresse 158/206723 : None, Livraison: Oui
# Traitement de l'adresse 159/206723 : None, Livraison: Non
# Traitement de l'adresse 160/206723 : None, Livraison: Non
# Traitement de l'adresse 161/206723 : http://www.atelierrichelieu.com/, Livraison: Non
# Traitement de l'adresse 162/206723 : http://www.atelierrichelieu.com/, Livraison: Oui
# Traitement de l'adresse 163/206723 : None, Livraison: Non
# Traitement de l'adresse 164/206723 : None, Livraison: Non
# Traitement de l'adresse 165/206723 : None, Livraison: Non
# Traitement de l'adresse 166/206723 : None, Livraison: Non
# Traitement de l'adresse 167/206723 : None, Livraison: Non
# Traitement de l'adresse 168/206723 : None, Livraison: Non
# Traitement de l'adresse 169/206723 : None, Livraison: Non
# Traitement de l'adresse 170/206723 : None, Livraison: Non
# Traitement de l'adresse 171/206723 : None, Livraison: Non
# Traitement de l'adresse 172/206723 : None, Livraison: Non
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 14
#      12 # Ouvrir l'URL dans le navigateur Selenium
#      13 driver.get(url)
# ---> 14 time.sleep(2)  # Pause pour charger la page
#      16 html = driver.page_source
#      17 soup = BeautifulSoup(html, "html.parser")
#
# KeyboardInterrupt:
